# %% [markdown]
# # Fantasy Baseball Rankings
#
# Uses the `Fantasy` class from `baseball.py` to rank all qualified MLB players by expected fantasy contribution under Yahoo standard public league scoring.
#
# **Three scoring modes:**
# - `points` — per-stat point values (e.g. HR = 10.4 pts)
# - `categories` — 5×5 head-to-head categories, valued by z-score
# - `roto` — 5×5 rotisserie, same z-score valuation
#
# **Also covers:** FanGraphs projection systems (Steamer, ZiPS, Depth Charts, etc.) via the `.projections` property on `Batters`, `Pitchers`, and `League`.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.path.dirname(os.path.abspath('__file__')), '..'))

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 120)

from baseball import (
    Fantasy, League, Batters, Pitchers,
    YAHOO_SCORING, PROJECTION_SYSTEMS,
)

print('baseball.py loaded.')
print(f'Projection systems available: {PROJECTION_SYSTEMS}')
# Out:
# baseball.py loaded.
# Projection systems available: ['steamer', 'steamerr', 'zips', 'zipr', 'atc', 'thebat', 'thebatx', 'fangraphs']

# %%
# ── CONFIG ──────────────────────────────────
SEASON = 2025
# ────────────────────────────────────────────

print(f'Season: {SEASON}')
print()
print('Yahoo scoring config:')
for mode, cfg in YAHOO_SCORING.items():
    print(f'  {mode}: {cfg}')
# Out:
# Season: 2025
#
# Yahoo scoring config:
#   categories: {'batting': ['R', 'HR', 'RBI', 'SB', 'AVG'], 'pitching': ['W', 'SV', 'SO', 'ERA', 'WHIP']}
#   roto: {'batting': ['R', 'HR', 'RBI', 'SB', 'AVG'], 'pitching': ['W', 'SV', 'SO', 'ERA', 'WHIP']}
#   points: {'batting': {'1B': 2.6, '2B': 5.2, '3B': 7.8, 'HR': 10.4, 'R': 1.9, 'RBI': 1.9, 'BB': 2.6, 'SB': 4.2, 'HBP': 2.6}, 'pitching': {'W': 8.0, 'SV': 8.0, 'SO': 3.0, 'Outs': 1.0, 'H': -1.3, 'BB': -1.3, 'HBP': -1.3, 'ER': -3.0}}

# %% [markdown]
# ## Fangrpahs Historical Player Data

# %%
league = League(SEASON).fetch()

print(f'Batters:  {len(league.batters)} total, {len(league.batters.qualified())} qualified (≥100 PA)')
print(f'Pitchers: {len(league.pitchers)} total, {len(league.pitchers.qualified())} qualified (≥20 IP)')
# Out:
# Batters:  1470 total, 461 qualified (≥100 PA)
# Pitchers: 873 total, 542 qualified (≥20 IP)

# %% [markdown]
# ### Top 300

# %%
league.batters.top(300)
# Out:
#        IDfg  Season              Name   Team  Age    G   AB   PA    H  1B  ...    xBA   xSLG  xwOBA  L-WAR  \
# rank                                                                       ...
# 1     15640    2025       Aaron Judge    NYY   33  152  541  679  179  94  ...  0.300  0.708  0.459   10.2
# 2     19755    2025     Shohei Ohtani    LAD   30  158  611  727  172  83  ...  0.274  0.649  0.425    7.2
# 3     35110    2025        Nick Kurtz    ATH   22  117  420  489  122  58  ...  0.245  0.537  0.372    4.5
# 4     12856    2025   George Springer    TOR   35  140  498  586  154  94  ...  0.291  0.571  0.404    5.4
# 5     18401    2025  Ronald Acuna Jr.    ATL   27   95  338  412   98  64  ...  0.263  0.535  0.397    3.2
# ...     ...     ...               ...    ...  ...  ...  ...  ...  ...  ..  ...    ...    ...    ...    ...
# 296   18042    2025       Dylan Moore  - - -   32  106  219  243   44  28  ...  0.191  0.326  0.262   -0.1
# 297   21707    2025   Oswaldo Cabrera    NYY   26   34  107  122   26  21  ...  0.244  0.297  0.284    0.1
# 298   29591    2025     Colton Cowser    BAL   25   92  327  360   64  34  ...  0.200  0.404  0.293    0.6
# 299   16376    2025  Michael Conforto    LAD   32  138  418  486   83  51  ...  0.233  0.410  0.330   -0.4
# 300   27647    2025     Anthony Volpe    NYY   24  153  539  596  114  59  ...  0.223  0.405  0.301    0.8
#
#       avg_hit_speed  max_hit_speed  brl_pa  brl_percent  player_id  Pos
# rank
# 1              95.4          118.1    14.1         24.7   592450.0  NaN
# 2              94.9          120.0    13.8         23.5   660271.0  NaN
# 3              92.7          114.6    10.2         18.4   701762.0  NaN
# 4              90.0          114.0    10.8         16.1   543807.0  NaN
# 5               NaN            NaN     NaN          NaN        NaN  NaN
# ...             ...            ...     ...          ...        ...  ...
# 296             NaN            NaN     NaN          NaN        NaN  NaN
# 297             NaN            NaN     NaN          NaN        NaN  NaN
# 298            90.9          113.7     7.8         14.1   681297.0  NaN
# 299            89.9          112.9     6.0          9.7   624424.0  NaN
# 300            89.3          110.5     7.0         10.5   683011.0  NaN
#
# [300 rows x 325 columns]

# %%
league.pitchers.top(300).sort_values(by='WAR', ascending=False)
# Out:
#        IDfg  Season                Name Team  Age   W   L  WAR   ERA   G  ...  si_avg_spin  fc_avg_spin  sl_avg_spin  \
# rank                                                                      ...
# 19    22267    2025        Tarik Skubal  DET   28  13   6  6.6  2.21  31  ...       2250.0          NaN       2233.0
# 14    33677    2025         Paul Skenes  PIT   23  10  10  6.5  1.97  32  ...       2268.0          NaN       2316.0
# 23    20778    2025  Cristopher Sanchez  PHI   28  13   5  6.4  2.50  32  ...          NaN          NaN          NaN
# 48    27463    2025     Garrett Crochet  BOS   26  18   5  5.8  2.59  32  ...       2399.0       2596.0          NaN
# 25    17995    2025          Logan Webb  SFG   28  15  11  5.5  3.22  34  ...       1961.0       2225.0          NaN
# ...     ...     ...                 ...  ...  ...  ..  ..  ...   ...  ..  ...          ...          ...          ...
# 252   26252    2025         Erik Miller  SFG   27   4   1  0.1  1.50  36  ...       2327.0          NaN       2614.0
# 255   19320    2025       Joey Lucchesi  SFG   32   0   1  0.1  3.76  38  ...       2277.0          NaN          NaN
# 274   24581    2025     Lyon Richardson  CIN   25   0   3  0.1  4.54  34  ...       2289.0          NaN       2638.0
# 231   21951    2025        Joel Peguero  SFG   28   3   1  0.0  2.42  17  ...       2347.0          NaN       2674.0
# 265   16128    2025        John Curtiss  ARI   32   3   2  0.0  3.93  30  ...          NaN       2540.0       2529.0
#
#       ch_avg_spin  cu_avg_spin  fs_avg_spin  kn_avg_spin  st_avg_spin  sv_avg_spin  Pos
# rank
# 19         1837.0       2505.0        941.0          NaN          NaN          NaN   SP
# 14         1808.0       2438.0       1676.0          NaN       2333.0          NaN   SP
# 23            NaN          NaN          NaN          NaN          NaN          NaN   SP
# 48         2099.0          NaN       1158.0          NaN       2378.0          NaN   SP
# 25         1502.0          NaN          NaN          NaN       2544.0          NaN   SP
# ...           ...          ...          ...          ...          ...          ...  ...
# 252        1938.0          NaN          NaN          NaN          NaN          NaN   RP
# 255           NaN       2172.0       1812.0          NaN          NaN          NaN   RP
# 274        1792.0       2541.0          NaN          NaN          NaN          NaN   RP
# 231           NaN          NaN          NaN          NaN          NaN          NaN   RP
# 265        1703.0          NaN          NaN          NaN          NaN          NaN   RP
#
# [300 rows x 405 columns]

# %% [markdown]
# ### Categories / Roto Rankings (Z-Score)
#
# No literal point totals exist in category leagues — player value is expressed as
# the sum of z-scores across all five batting or pitching categories.
#
# Rate stats are weighted by playing time before z-scoring:
# - `AVG` → `excess_hits = (AVG − pool_mean) × AB`
# - `ERA` → `era_contrib = (pool_mean − ERA) × IP / 9`
# - `WHIP` → `whip_contrib = (pool_mean − WHIP) × IP`

# %%
f_cat = Fantasy(SEASON, 'categories', league=league)
df_cat = f_cat.rank()

print(f'Ranked {len(df_cat)} players')
print(f'Z-score columns: {[c for c in df_cat.columns if c.startswith("z_")]}')
# Out:
# Ranked 1003 players
# Z-score columns: ['z_R', 'z_HR', 'z_RBI', 'z_SB', 'z_AVG', 'z_W', 'z_SV', 'z_SO', 'z_ERA', 'z_WHIP']

# %%
# Top 20 overall by z-score
# df_cat[DISPLAY_COLS].head(20)

# %%
# Top batters with z-score breakdown
bat_z_cols = ['Name', 'Pos', 'Team', 'fantasy_score', 'z_HR', 'z_R', 'z_RBI', 'z_SB', 'z_AVG']
bat_z_cols_avail = [c for c in bat_z_cols if c in df_cat.columns]

df_cat[df_cat.player_type == 'batter'][bat_z_cols_avail].head(40).round(3)
# Out:
#                        Name  Pos   Team  fantasy_score   z_HR    z_R  z_RBI   z_SB  z_AVG
# rank
# 1               Aaron Judge  NaN    NYY         14.764  4.033  3.362  2.549  0.567  4.253
# 4             Shohei Ohtani  NaN    LAD         13.622  4.229  3.691  2.115  1.480  2.107
# 5                 Juan Soto  NaN    NYM         12.524  3.051  2.741  2.223  3.532  0.977
# 7              Jose Ramirez  NaN    CLE         11.702  1.774  2.120  1.500  4.216  2.092
# 10           Bobby Witt Jr.  NaN    KCR         11.093  1.086  1.974  1.608  3.532  2.892
# 12              Cal Raleigh  NaN    SEA         10.987  4.720  2.376  2.947  0.795  0.148
# 17         Francisco Lindor  NaN    NYM         10.128  1.872  2.632  1.536  2.734  1.355
# 19          Julio Rodriguez  NaN    SEA         10.056  1.970  2.230  1.861  2.620  1.375
# 20           Kyle Schwarber  NaN    PHI         10.048  4.328  2.412  3.200  0.339 -0.232
# 22          George Springer  NaN    TOR          9.810  1.970  2.230  1.463  1.251  2.896
# 23          Geraldo Perdomo  NaN    ARI          9.538  0.792  1.937  2.042  2.278  2.489
# 24              Trea Turner  NaN    PHI          9.520  0.300  1.791  0.921  3.304  3.203
# 27           Corbin Carroll  NaN    ARI          9.193  1.872  2.266  1.463  2.848  0.743
# 28          Elly De La Cruz  NaN    CIN          9.171  0.988  2.084  1.536  3.418  1.145
# 30              Josh Naylor  NaN  - - -          8.968  0.792  1.316  1.753  2.620  2.488
# 31       Fernando Tatis Jr.  NaN    SDP          8.820  1.283  2.412  0.993  2.848  1.284
# 32      Pete Crow-Armstrong  NaN    CHC          8.750  1.872  1.682  1.861  3.190  0.145
# 33             Trevor Story  NaN    BOS          8.647  1.283  1.682  1.898  2.734  1.051
# 34          Junior Caminero  NaN    TBR          8.488  3.247  1.755  2.404 -0.003  1.085
# 38             Byron Buxton  NaN    MIN          8.360  2.265  1.901  1.427  1.936  0.831
# 40             Brice Turang  NaN    MIL          8.109  0.595  1.901  1.355  1.936  2.322
# 42              Pete Alonso  NaN    NYM          7.980  2.560  1.536  2.983 -0.687  1.589
# 46            Manny Machado  NaN    SDP          7.548  1.479  1.682  1.861  0.795  1.731
# 47         Christian Yelich  NaN    MIL          7.442  1.676  1.572  2.151  1.023  1.020
# 48           Cody Bellinger  NaN    NYY          7.418  1.676  1.609  1.970  0.681  1.482
# 50             Nico Hoerner  NaN    CHC          7.140 -0.485  1.609  0.631  2.506  2.880
# 52         Gunnar Henderson  NaN    BAL          7.019  0.497  1.463  0.884  2.620  1.555
# 53            Maikel Garcia  NaN    KCR          6.901  0.399  1.316  1.102  1.822  2.262
# 54          Randy Arozarena  NaN    SEA          6.872  1.479  1.828  1.174  2.734 -0.343
# 55        Jazz Chisholm Jr.  NaN    NYY          6.868  1.872  1.097  1.319  2.734 -0.153
# 57    Vladimir Guerrero Jr.  NaN    TOR          6.856  1.086  1.864  1.463 -0.117  2.559
# 58              Bo Bichette  NaN    TOR          6.816  0.595  1.207  1.825 -0.345  3.534
# 60           Eugenio Suarez  NaN  - - -          6.795  3.640  1.682  2.694 -0.345 -0.876
# 61               James Wood  NaN    WSN          6.782  1.872  1.536  1.825  0.909  0.640
# 64              Kyle Tucker  NaN    CHC          6.734  0.988  1.682  1.065  2.050  0.949
# 67               Nick Kurtz  NaN    ATH          6.645  2.363  1.645  1.536 -0.573  1.675
# 68          Freddie Freeman  NaN    LAD          6.618  1.184  1.316  1.680 -0.117  2.553
# 70          Jackson Chourio  NaN    MIL          6.569  0.890  1.572  1.246  1.594  1.267
# 71               Yandy Diaz  NaN    TBR          6.450  1.283  1.243  1.427 -0.459  2.956
# 72             Riley Greene  NaN    DET          6.409  2.363  1.426  2.440 -0.573  0.752

# %%
df_cat[df_cat.Name.str.contains('Eugen')][bat_z_cols_avail]
# Out:
#                 Name  Pos   Team  fantasy_score      z_HR       z_R    z_RBI      z_SB     z_AVG
# rank
# 60    Eugenio Suarez  NaN  - - -       6.794719  3.640006  1.681728  2.69368 -0.345084 -0.875611

# %%
# Top 10 pitchers with z-score breakdown
pit_z_cols = ['Name', 'Team', 'fantasy_score', 'z_W', 'z_SV', 'z_SO', 'z_ERA', 'z_WHIP']
pit_z_cols_avail = [c for c in pit_z_cols if c in df_cat.columns]

df_cat[df_cat.player_type == 'pitcher'][pit_z_cols_avail].head(10).round(3)
# Out:
#                     Name Team  fantasy_score    z_W   z_SV   z_SO  z_ERA  z_WHIP
# rank
# 2           Tarik Skubal  DET         14.122  2.426 -0.356  3.671  3.739   4.641
# 3        Garrett Crochet  BOS         13.734  3.827 -0.356  3.973  3.150   3.139
# 6            Paul Skenes  PIT         12.163  1.586 -0.356  3.131  4.037   3.764
# 8              Bryan Woo  SEA         11.535  2.987 -0.356  2.743  2.191   3.970
# 9     Cristopher Sanchez  PHI         11.121  2.426 -0.356  3.045  3.284   2.721
# 11          Carlos Rodon  NYY         11.070  3.827 -0.356  2.851  2.006   2.742
# 13             Max Fried  NYY         10.907  4.107 -0.356  2.548  2.459   2.148
# 14        Freddy Peralta  MIL         10.698  3.547 -0.356  2.872  2.494   2.141
# 15          Hunter Brown  HOU         10.656  2.146 -0.356  2.915  3.130   2.819
# 16    Yoshinobu Yamamoto  LAD         10.465  2.146 -0.356  2.807  2.817   3.050

# %% [markdown]
# ### Roto

# %%
# Roto — same z-score logic, identical structure
f_roto = Fantasy(SEASON, 'roto', league=league)
df_roto = f_roto.rank()
df_roto
# df_roto[DISPLAY_COLS].head(10)
# Out:
#        IDfg  Season               Name   Team  Age    G     AB     PA    H    1B  ...  cu_avg_spin  fs_avg_spin  \
# rank                                                                              ...
# 1     15640    2025        Aaron Judge    NYY   33  152  541.0  679.0  179  94.0  ...          NaN          NaN
# 2     22267    2025       Tarik Skubal    DET   28   31    NaN    NaN  141   NaN  ...       2505.0        941.0
# 3     27463    2025    Garrett Crochet    BOS   26   32    NaN    NaN  165   NaN  ...          NaN       1158.0
# 4     19755    2025      Shohei Ohtani    LAD   30  158  611.0  727.0  172  83.0  ...          NaN          NaN
# 5     20123    2025          Juan Soto    NYM   26  160  577.0  715.0  152  88.0  ...          NaN          NaN
# ...     ...     ...                ...    ...  ...  ...    ...    ...  ...   ...  ...          ...          ...
# 999   13723    2025    Jacob Stallings  - - -   35   43  119.0  129.0   16  12.0  ...          NaN          NaN
# 1000  27688    2025   Jack Kochanowicz    LAA   24   23    NaN    NaN  136   NaN  ...          NaN          NaN
# 1001  15038    2025     German Marquez    COL   30   26    NaN    NaN  168   NaN  ...          NaN          NaN
# 1002  26419    2025    Bradley Blalock    COL   24   14    NaN    NaN   85   NaN  ...       2511.0       1322.0
# 1003  15488    2025  Antonio Senzatela    COL   30   30    NaN    NaN  192   NaN  ...       2463.0          NaN
#
#       kn_avg_spin  st_avg_spin  sv_avg_spin       z_W      z_SV      z_SO     z_ERA    z_WHIP
# rank
# 1             NaN          NaN          NaN       NaN       NaN       NaN       NaN       NaN
# 2             NaN          NaN          NaN  2.426393 -0.355541  3.670878  3.739108  4.641446
# 3             NaN       2378.0          NaN  3.826931 -0.355541  3.973075  3.149852  3.139278
# 4             NaN          NaN          NaN       NaN       NaN       NaN       NaN       NaN
# 5             NaN          NaN          NaN       NaN       NaN       NaN       NaN       NaN
# ...           ...          ...          ...       ...       ...       ...       ...       ...
# 999           NaN          NaN          NaN       NaN       NaN       NaN       NaN       NaN
# 1000          NaN       2842.0          NaN -0.374683 -0.355541  0.022940 -3.077331 -3.230163
# 1001          NaN          NaN          NaN -0.374683 -0.355541  0.260379 -3.340197 -3.343180
# 1002          NaN          NaN          NaN -0.654790 -0.355541 -0.948405 -3.166800 -2.080416
# 1003          NaN          NaN          NaN -0.094575 -0.355541  0.044525 -3.374305 -4.470609
#
# [1003 rows x 465 columns]

# %% [markdown]
# ### Points

# %%
f_pts = Fantasy(SEASON, 'points', league=league)
df_pts = f_pts.rank()
df_pts
# Out:
#        IDfg  Season              Name Team  Age    G     AB     PA    H    1B  ...  kn_avg_spin  st_avg_spin  \
# rank                                                                           ...
# 1     15640    2025       Aaron Judge  NYY   33  152  541.0  679.0  179  94.0  ...          NaN          NaN
# 2     19755    2025     Shohei Ohtani  LAD   30  158  611.0  727.0  172  83.0  ...          NaN          NaN
# 3     20123    2025         Juan Soto  NYM   26  160  577.0  715.0  152  88.0  ...          NaN          NaN
# 4     16478    2025    Kyle Schwarber  PHI   32  162  604.0  724.0  145  64.0  ...          NaN          NaN
# 5     21534    2025       Cal Raleigh  SEA   28  159  596.0  705.0  147  63.0  ...          NaN          NaN
# ...     ...     ...               ...  ...  ...  ...    ...    ...  ...   ...  ...          ...          ...
# 999   19614    2025      Cionel Perez  BAL   29   19    NaN    NaN   28   NaN  ...          NaN          NaN
# 1000  16561    2025     Austin Gomber  COL   31   12    NaN    NaN   82   NaN  ...          NaN          NaN
# 1001  23135    2025   Eduardo Salazar  WSN   27   30    NaN    NaN   47   NaN  ...          NaN          NaN
# 1002  31612    2025  Carson Palmquist  COL   24    9    NaN    NaN   45   NaN  ...          NaN       1984.0
# 1003  26419    2025   Bradley Blalock  COL   24   14    NaN    NaN   85   NaN  ...          NaN          NaN
#
#       sv_avg_spin   Outs  pts_W  pts_SV  pts_SO  pts_Outs  pts_H  pts_ER
# rank
# 1             NaN    NaN    NaN     NaN     NaN       NaN    NaN     NaN
# 2             NaN    NaN    NaN     NaN     NaN       NaN    NaN     NaN
# 3             NaN    NaN    NaN     NaN     NaN       NaN    NaN     NaN
# 4             NaN    NaN    NaN     NaN     NaN       NaN    NaN     NaN
# 5             NaN    NaN    NaN     NaN     NaN       NaN    NaN     NaN
# ...           ...    ...    ...     ...     ...       ...    ...     ...
# 999           NaN   65.0    0.0     0.0    63.0      65.0  -36.4   -60.0
# 1000          NaN  173.0    0.0     0.0   102.0     173.0 -106.6  -144.0
# 1001          NaN   87.0    0.0     0.0    69.0      87.0  -61.1   -81.0
# 1002          NaN  103.0    0.0     0.0    81.0     103.0  -58.5  -102.0
# 1003          NaN  176.0   16.0     0.0    81.0     176.0 -110.5  -183.0
#
# [1003 rows x 471 columns]

# %% [markdown]
# ## FanGraphs Projections
#
# `.projections` is a lazy property on `Batters`, `Pitchers`, and `League` — fetched from the FanGraphs public JSON API on first access, then cached.
#
# Available systems: `steamer`, `steamerr`, `zips`, `zipr`, `atc`, `thebat`, `thebatx`, `fangraphs` (Depth Charts).
#
# > **Note:** `fangraphs` (Depth Charts) and `zipr` are preseason-only — they return errors for completed seasons. Use `steamer`, `zips`, `atc`, `thebat`, or `thebatx` for historical data.

# %% [markdown]
# ### Raw Projections

# %%
league.batters.projections
# Out:
#     Team ShortName       G        AB        PA         H       1B       2B      3B       HR  ...         ADP  \
# 0    NYY   Yankees  141.06  508.6050  633.3190  143.7100  76.8967  23.3104  1.2047  42.2986  ...    1.910000
# 1    KCR    Royals  139.93  573.6200  633.6550  168.0650  98.9622  36.4332  4.6989  27.9706  ...    2.950000
# 2    BAL   Orioles  145.86  581.8140  665.5350  159.7610  95.6800  31.6841  4.2666  28.1302  ...   12.060000
# 3    SEA  Mariners  137.84  527.3290  614.6470  121.5080  61.6391  21.8662  0.4719  37.5310  ...   17.879999
# 4    SEA  Mariners  138.87  559.9820  617.6850  154.0000  95.1425  26.6806  2.3466  29.8301  ...    9.680000
# ..   ...       ...     ...       ...       ...       ...      ...      ...     ...      ...  ...         ...
# 662  LAA    Angels   27.23   97.9804  109.9960   20.9437  13.9967   4.3623  0.3015   2.2832  ...  999.000000
# 663  PHI  Phillies   19.19   76.0932   82.3535   17.8354  11.8109   3.2480  0.1316   2.6449  ...  999.000000
# 664  COL   Rockies   52.94  186.7900  206.3070   47.6053  31.7354   8.9558  1.4185   5.4956  ...  999.000000
# 665  COL   Rockies   17.73   66.6620   74.2905   15.9209  10.5120   3.0488  0.2516   2.1085  ...  999.000000
# 666  ATL    Braves   46.91  166.1340  185.2130   40.5665  28.2082   7.5720  0.3521   4.4341  ...  999.000000
#
#           Pos  minpos                                          UPURL  teamid  League        PlayerName  xMLBAMID  \
# 0    0.370861      OF       /players/aaron-judge/15640/stats/batting     9.0      AL       Aaron Judge  592450.0
# 1    0.025316      SS     /players/bobby-witt-jr/25764/stats/batting     7.0      AL    Bobby Witt Jr.  677951.0
# 2    0.052288      SS  /players/gunnar-henderson/26289/stats/batting     2.0      AL  Gunnar Henderson  683002.0
# 3    0.238994       C       /players/cal-raleigh/21534/stats/batting    11.0      AL       Cal Raleigh  663728.0
# 4    0.006250      OF   /players/julio-rodriguez/23697/stats/batting    11.0      AL   Julio Rodríguez  677594.0
# ..        ...     ...                                            ...     ...     ...               ...       ...
# 662  0.000000      OF      /players/chris-taylor/13757/stats/batting     1.0      AL      Chris Taylor  621035.0
# 663  0.066667      OF  /players/bryan-de-la-cruz/19600/stats/batting    26.0      NL  Bryan De La Cruz  650559.0
# 664  0.111111   1B/OF     /players/troy-johnston/26143/stats/batting    19.0      NL     Troy Johnston  687859.0
# 665  1.000000   3B/OF       /players/kris-bryant/15429/stats/batting    19.0      NL       Kris Bryant  592178.0
# 666  0.100000   1B/OF     /players/dominic-smith/15653/stats/batting    16.0      NL     Dominic Smith  642086.0
#
#     playerids  playerid
# 0       15640     15640
# 1       25764     25764
# 2       26289     26289
# 3       21534     21534
# 4       23697     23697
# ..        ...       ...
# 662     13757     13757
# 663     19600     19600
# 664     26143     26143
# 665     15429     15429
# 666     15653     15653
#
# [667 rows x 80 columns]

# %%
# Steamer batting projections — filtered to players in our FanGraphs pool
bat_proj = league.batters.projections
print(f'Steamer batting projections: {bat_proj.shape}')

PROJ_BAT_COLS = ['PlayerName', 'Team', 'G', 'PA', 'AB', 'HR', 'R', 'RBI', 'SB', 'AVG', 'OBP', 'SLG']
proj_bat_cols_avail = [c for c in PROJ_BAT_COLS if c in bat_proj.columns]
bat_proj[proj_bat_cols_avail].head(10)
# Out:
# Steamer batting projections: (667, 80)
#               PlayerName Team       G       PA       AB       HR         R       RBI       SB       AVG       OBP  \
# 0            Aaron Judge  NYY  141.06  633.319  508.605  42.2986  108.8040  102.3580   8.8032  0.282558  0.415219
# 1         Bobby Witt Jr.  KCR  139.93  633.655  573.620  27.9706   98.8669   88.5602  31.2113  0.292990  0.350712
# 2       Gunnar Henderson  BAL  145.86  665.535  581.814  28.1302  100.6510   83.8073  23.5706  0.274591  0.356857
# 3            Cal Raleigh  SEA  137.84  614.647  527.329  37.5310   88.6474   90.9235   8.0118  0.230422  0.330965
# 4        Julio Rodríguez  SEA  138.87  617.685  559.982  29.8301   85.2447   91.2925  22.5962  0.275008  0.334455
# 5              Juan Soto  NYM  137.61  621.171  493.934  34.2492  104.9420   88.6847  19.6566  0.273022  0.413052
# 6          Shohei Ohtani  LAD  142.27  658.176  554.639  43.5958  119.8340   99.3561  22.2879  0.275289  0.379961
# 7       Ronald Acuña Jr.  ATL  147.08  676.219  570.607  30.8135  109.2420   84.0682  24.1561  0.285575  0.388027
# 8  Vladimir Guerrero Jr.  TOR  143.49  636.639  551.164  32.1753   93.6262   98.9880   4.7888  0.296716  0.383060
# 9     Fernando Tatis Jr.  SDP  130.47  579.399  505.142  28.5147   85.6611   82.6729  21.1598  0.274755  0.359588
#
#         SLG
# 0  0.582625
# 1  0.519172
# 2  0.488762
# 3  0.487193
# 4  0.490844
# 5  0.532644
# 6  0.577693
# 7  0.503374
# 8  0.530674
# 9  0.502534

# %%
# Steamer pitching projections — filtered to players in our FanGraphs pool
pit_proj = league.pitchers.projections
print(f'Steamer pitching projections: {pit_proj.shape}')

PROJ_PIT_COLS = ['PlayerName', 'Team', 'G', 'GS', 'IP', 'W', 'SV', 'SO', 'ERA', 'WHIP', 'FIP']
proj_pit_cols_avail = [c for c in PROJ_PIT_COLS if c in pit_proj.columns]
pit_proj[proj_pit_cols_avail].head(10)
# Out:
# Steamer pitching projections: (803, 68)
#            PlayerName Team      G     GS       IP        W   SV       SO      ERA     WHIP      FIP
# 0        Tarik Skubal  DET  32.00  32.00  199.765  14.1293  0.0  242.838  2.78986  1.01477  2.78279
# 1         Paul Skenes  PIT  32.00  32.00  193.982  13.5495  0.0  236.968  2.92097  1.08137  2.77894
# 2     Garrett Crochet  BOS  32.00  32.00  192.855  13.6166  0.0  238.635  3.01991  1.07560  2.84475
# 3  Cristopher Sánchez  PHI  32.00  32.00  198.055  13.5510  0.0  191.365  3.14789  1.17764  3.22250
# 4          Chris Sale  ATL  27.54  27.54  168.535  11.8616  0.0  205.598  3.18998  1.09115  3.03503
# 5          Logan Webb  SFG  32.00  32.00  199.392  12.6793  0.0  187.379  3.31630  1.20850  3.13980
# 6         Cole Ragans  KCR  29.16  29.16  172.018  11.7976  0.0  210.676  3.31035  1.17546  3.30278
# 7        Jacob deGrom  TEX  29.16  29.16  174.797  11.4058  0.0  202.732  3.51935  1.09999  3.34551
# 8         Dylan Cease  TOR  32.00  32.00  184.857  12.3623  0.0  217.090  3.53880  1.20559  3.52155
# 9          Sonny Gray  BOS  30.78  30.78  181.357  11.5579  0.0  189.679  3.69224  1.20834  3.44458

# %%
# Combined — League.projections adds a player_type column
combined_proj = league.projections
print(f'Combined projections: {combined_proj.shape}')
print(f'player_type breakdown:\n{combined_proj["player_type"].value_counts().to_string()}')
# Out:
# Combined projections: (1470, 107)
# player_type breakdown:
# player_type
# pitcher    803
# batter     667

# %%
# ZiPS projections — pass proj_system at construction
league_zips = League(SEASON, proj_system='zips')
zips_bat = league_zips.batters.projections  # triggers historical fetch + projection filter

print(f'ZiPS batting projections: {zips_bat.shape}')
zips_cols = [c for c in PROJ_BAT_COLS if c in zips_bat.columns]
zips_bat[zips_cols].head(5)
# Out:
# ZiPS batting projections: (668, 57)
#        PlayerName Team    G   PA   AB  HR    R  RBI  SB       AVG       OBP       SLG
# 0     Aaron Judge  NYY  141  624  500  42  107  115   8  0.288000  0.421474  0.594000
# 1   Shohei Ohtani  LAD  152  696  592  52  138  138  29  0.288851  0.389368  0.619932
# 2     Cal Raleigh  SEA  152  621  538  41   82  108   7  0.230483  0.328502  0.500000
# 3  Bobby Witt Jr.  KCR  152  658  598  27   98   93  32  0.282609  0.337386  0.505017
# 4       Juan Soto  NYM  152  670  538  37  109  103  23  0.271375  0.408072  0.524164

# %%
# The BAT projections — another well-regarded system
league_bat = League(SEASON, proj_system='thebat')
thebat_proj = league_bat.batters.projections

print(f'The BAT batting projections: {thebat_proj.shape}')
thebat_cols = [c for c in PROJ_BAT_COLS if c in thebat_proj.columns]
thebat_proj[thebat_cols].head(5)
# Out:
# The BAT batting projections: (594, 57)
#        PlayerName Team        G       PA       AB       HR        R       RBI        SB       AVG       OBP       SLG
# 0     Aaron Judge  NYY  145.012  637.496  517.791  48.6834  104.880  117.7720   8.02032  0.287485  0.413526  0.619083
# 1     Cal Raleigh  SEA  149.940  623.786  538.839  43.6769   87.716  111.4550   7.74883  0.234386  0.330743  0.522046
# 2   Shohei Ohtani  LAD  148.296  659.513  559.505  46.7980  121.940  115.7870  23.20900  0.284317  0.385365  0.602475
# 3       Juan Soto  NYM  154.010  674.968  544.640  37.1906  106.390   96.6763  17.26140  0.266715  0.401647  0.519285
# 4  Bobby Witt Jr.  KCR  151.311  659.880  599.248  27.1172  100.200   90.9679  34.88440  0.284801  0.340966  0.501298

# %% [markdown]
# ### Fantasy Score Estimate based on Projections

# %%
SCORING_TYPE = 'categories'  # 'points', 'categories', or 'roto'
PROJ_SYSTEM  = 'atc'

league = League(SEASON, proj_system=PROJ_SYSTEM)
f = Fantasy(SEASON, SCORING_TYPE, league=league, use_projections=True)
df = f.rank()

score_cols = [c for c in df.columns if c.startswith(('pts_', 'z_'))]
df[['Name', 'Pos', 'fantasy_score'] + score_cols].sort_values('fantasy_score', ascending=False).iloc[:24]
# Out:
#                     Name       Pos  fantasy_score       z_R      z_HR     z_RBI      z_SB     z_AVG       z_W  \
# rank
# 1           Tarik Skubal       NaN      19.387300       NaN       NaN       NaN       NaN       NaN  3.265969
# 2            Paul Skenes       NaN      16.897344       NaN       NaN       NaN       NaN       NaN  2.595715
# 3        Garrett Crochet       NaN      15.373492       NaN       NaN       NaN       NaN       NaN  3.122860
# 4          Shohei Ohtani  0.918605      14.769609  3.073733  3.896193  2.611489  2.166608  3.021587       NaN
# 5              Bryan Woo       NaN      13.589450       NaN       NaN       NaN       NaN       NaN  3.018732
# 6         Bobby Witt Jr.  0.025316      13.143947  2.166891  1.825231  1.904679  3.397539  3.849607       NaN
# 7            Aaron Judge  0.370861      12.479709  2.464166  3.905084  2.717685  0.178759  3.214014       NaN
# 8     Cristopher Sánchez       NaN      11.857691       NaN       NaN       NaN       NaN       NaN  2.586960
# 9              Juan Soto  0.018750      11.661653  2.525379  2.988642  2.198405  1.785296  2.163931       NaN
# 10            Chris Sale       NaN      11.641136       NaN       NaN       NaN       NaN       NaN  2.239659
# 11            Logan Webb       NaN      11.529325       NaN       NaN       NaN       NaN       NaN  2.995013
# 12         Logan Gilbert       NaN      11.373742       NaN       NaN       NaN       NaN       NaN  2.016671
# 13    Yoshinobu Yamamoto       NaN      11.219651       NaN       NaN       NaN       NaN       NaN  2.667104
# 14          José Ramírez  0.162500      10.990969  1.854753  1.758354  1.774788  3.328683  2.274391       NaN
# 15             Max Fried       NaN      10.983772       NaN       NaN       NaN       NaN       NaN  3.191243
# 16          Jacob deGrom       NaN      10.662430       NaN       NaN       NaN       NaN       NaN  1.957901
# 17       Julio Rodríguez  0.006250      10.539736  1.891697  1.944844  1.866968  2.629181  2.207046       NaN
# 18      Ronald Acuña Jr.  0.042105      10.346839  2.393266  1.807778  1.310522  2.255051  2.580223       NaN
# 19          Mason Miller       NaN      10.137553       NaN       NaN       NaN       NaN       NaN -0.318251
# 20          Hunter Brown       NaN      10.071129       NaN       NaN       NaN       NaN       NaN  2.641832
# 21       Elly De La Cruz  0.024691       9.742388  1.876357  1.182125  1.315996  4.278071  1.089839       NaN
# 22            Edwin Díaz       NaN       9.673686       NaN       NaN       NaN       NaN       NaN  0.246055
# 23    Fernando Tatis Jr.  0.012903       9.639482  2.070469  1.818297  1.452469  2.334221  1.964027       NaN
# 24         Jesús Luzardo       NaN       9.494482       NaN       NaN       NaN       NaN       NaN  2.569220
#
#           z_SV      z_SO     z_ERA    z_WHIP
# rank
# 1    -0.345788  3.511133  6.326971  6.629016
# 2    -0.345788  3.354070  6.010928  5.282420
# 3    -0.345788  3.365298  4.658676  4.572446
# 4          NaN       NaN       NaN       NaN
# 5    -0.345788  2.559686  3.204024  5.152796
# 6          NaN       NaN       NaN       NaN
# 7          NaN       NaN       NaN       NaN
# 8    -0.345788  2.435663  4.145186  3.035670
# 9          NaN       NaN       NaN       NaN
# 10   -0.345788  2.711523  3.517805  3.517937
# 11   -0.345788  2.501721  3.826140  2.552239
# 12   -0.345788  2.527513  2.752579  4.422768
# 13   -0.345788  2.315554  3.364056  3.218726
# 14         NaN       NaN       NaN       NaN
# 15   -0.345788  2.221770  3.469374  2.447175
# 16   -0.345788  2.374764  2.596437  4.079117
# 17         NaN       NaN       NaN       NaN
# 18         NaN       NaN       NaN       NaN
# 19    5.420942  0.629661  2.450795  1.954407
# 20   -0.345788  2.733846  2.724685  2.316553
# 21         NaN       NaN       NaN       NaN
# 22    5.960089  0.411296  1.609710  1.446535
# 23         NaN       NaN       NaN       NaN
# 24   -0.345788  2.735447  2.027205  2.508397

# %% [markdown]
# ## Yahoo Average Draft Position (ADP)
#
# Fetches ADP from Yahoo's public draft analysis API (`out=draft_analysis`).
# Sorted by `average_pick` ascending — lower = earlier pick.
#
# **Requires:** `browser/yahoo_oauth.json` (run Section 2 of `yahoo_fantasy_baseball.ipynb` first).

# %%
import logging
import sys; sys.path.insert(0, '..')
from yahoo import Yahoo

logging.getLogger('yahoo_oauth').setLevel(logging.WARNING)

CREDS_FILE = '../browser/yahoo_oauth.json'
ADP_COUNT  = 300
ADP_SEASON = 2026  # upcoming season — ADP is pre-season draft data, separate from SEASON

yf = Yahoo(season=ADP_SEASON, creds_file=CREDS_FILE)
yahoo_adp = yf.adp(ADP_COUNT)

print(f'Yahoo ADP ({ADP_SEASON}) — {len(yahoo_adp)} players')
yahoo_adp
# Out:
# Yahoo ADP (2026) — 300 players
#                         name team positions    adp  avg_round  pct_drafted
# rank
# 1                Aaron Judge  NYY        OF    1.5        1.0        100.0
# 2     Shohei Ohtani (Batter)  LAD      Util    1.7        1.0        100.0
# 3             Bobby Witt Jr.   KC        SS    3.6        1.0        100.0
# 4                  Juan Soto  NYM        OF    4.2        1.0        100.0
# 5               Tarik Skubal  DET        SP    5.7        1.0        100.0
# ...                      ...  ...       ...    ...        ...          ...
# 296           Edward Cabrera  CHC        SP  203.4       21.0         88.0
# 297              Jake Burger  TEX        1B  203.6       20.8          4.0
# 298              Clay Holmes  NYM        SP  203.9       21.0         10.0
# 299             Ryan Jeffers  MIN         C  204.4       20.9          4.0
# 300               Kris Bubic   KC        SP  205.4       21.0         24.0
#
# [300 rows x 6 columns]

# %% [markdown]
# ## Draft Value — Projected Points vs ADP
#
# Players where projected points rank is significantly better than ADP rank are undervalued picks.
# `value = adp_rank − pts_rank` — higher is better (drafted later than they should be).

# %%
SCORING_TYPE = 'roto'   # 'points', 'categories', or 'roto'

_df_map = {'points': df_pts, 'categories': df_cat, 'roto': df_roto}
if SCORING_TYPE not in _df_map:
    raise ValueError(f"SCORING_TYPE must be one of {list(_df_map)}")

value_df = yf.draft_value(_df_map[SCORING_TYPE])

print(f'Scoring: {SCORING_TYPE}  |  {len(value_df)} matched  |  {ADP_COUNT - len(value_df)} unmatched')
print(f'\nTop 30 undervalued — drafted much later than {SCORING_TYPE} rankings suggest:')
value_df.head(30)
# Out:
# Scoring: roto  |  291 matched  |  9 unmatched
#
# Top 30 undervalued — drafted much later than roto rankings suggest:
#                          name player_type positions    adp  adp_rank  fantasy_rank  fantasy_score  value
# rank
# 1                Matthew Boyd     pitcher        SP  194.9       241            45       7.830214    196
# 2                 Sal Frelick      batter        OF  202.6       292           103       5.283451    189
# 3                Carlos Rodón     pitcher        SP  187.9       196            11      11.069622    185
# 4                  Kris Bubic     pitcher        SP  205.4       300           144       4.077962    156
# 5             Jameson Taillon     pitcher        SP  201.9       287           133       4.303245    154
# 6               Robert Suarez     pitcher        RP  185.7       188            35       8.486589    153
# 7                  Casey Mize     pitcher        SP  201.5       284           136       4.216675    148
# 8                 Clay Holmes     pitcher        SP  203.9       298           152       3.777286    146
# 9                Brayan Bello     pitcher        SP  199.9       277           132       4.304123    145
# 10             Drew Rasmussen     pitcher        SP  189.1       199            59       6.804607    140
# 11             Adrian Morejon     pitcher        RP  194.1       233            95       5.581142    138
# 12             Edward Cabrera     pitcher        SP  203.4       296           163       3.526502    133
# 13               Bryson Stott      batter     2B,SS  198.2       269           141       4.157090    128
# 14            Jeffrey Springs     pitcher        SP  200.2       280           156       3.661546    124
# 15              Chris Bassitt     pitcher        SP  203.1       294           171       3.276289    123
# 16               Brandon Lowe      batter        2B  195.0       243           126       4.586907    117
# 17                  Will Vest     pitcher        RP  194.2       235           118       4.884682    117
# 18                Ryne Nelson     pitcher     SP,RP  193.6       230           115       4.912827    115
# 19             Quinn Priester     pitcher     SP,RP  193.4       227           114       4.980206    113
# 20               Zack Wheeler     pitcher        SP  141.5       137            29       9.049445    108
# 21             Nathan Eovaldi     pitcher        SP  136.2       132            26       9.208256    106
# 22              Andrew Abbott     pitcher        SP  179.8       178            77       6.277132    101
# 23               Emilio Pagán     pitcher        RP  162.3       164            66       6.675562     98
# 24           Chandler Simpson      batter        OF  192.5       216           127       4.537273     89
# 25                Luis Arraez      batter     1B,2B  193.2       225           139       4.172885     86
# 26                 Eric Lauer     pitcher     SP,RP  195.8       248           162       3.560934     86
# 27                Abner Uribe     pitcher        RP  195.6       245           159       3.629910     86
# 28    Shohei Ohtani (Pitcher)      batter        SP   92.2        89             4      13.622081     85
# 29              Kenley Jansen     pitcher        RP  161.9       163            78       6.238270     85
# 30               Trevor Story      batter        SS  120.7       116            33       8.647389     83
